# %%
import argparse
import sys
import os
import json
import torch
import os
import random
import utils
import data_utils
import json

import cbm
import plots
def parse_args():
    parser = argparse.ArgumentParser(description='Settings for creating CBM')
    # parser.add_argument('--batch_size', default=64, type=int)
    # parser.add_argument('--epochs', default=30, type=int)
    parser.add_argument('--update_freq', default=1, type=int)
    parser.add_argument('--save_ckpt_freq', default=100, type=int)

    # Model parameters
    parser.add_argument('--model', default='vit_base_patch16_224', type=str, metavar='MODEL',
                        help='Name of model to train')
    parser.add_argument('--tubelet_size', type=int, default= 2)
    parser.add_argument('--input_size', default=224, type=int,
                        help='videos input size')

    parser.add_argument('--fc_drop_rate', type=float, default=0.0, metavar='PCT',
                        help='Dropout rate (default: 0.)')
    parser.add_argument('--drop', type=float, default=0.0, metavar='PCT',
                        help='Dropout rate (default: 0.)')
    parser.add_argument('--attn_drop_rate', type=float, default=0.0, metavar='PCT',
                        help='Attention dropout rate (default: 0.)')
    parser.add_argument('--drop_path', type=float, default=0.1, metavar='PCT',
                        help='Drop path rate (default: 0.1)')

    parser.add_argument('--disable_eval_during_finetuning', action='store_true', default=False)
    parser.add_argument('--model_ema', action='store_true', default=False)
    parser.add_argument('--model_ema_decay', type=float, default=0.9999, help='')
    parser.add_argument('--model_ema_force_cpu', action='store_true', default=False, help='')

    # Optimizer parameters
    parser.add_argument('--opt', default='adamw', type=str, metavar='OPTIMIZER',
                        help='Optimizer (default: "adamw"')
    parser.add_argument('--opt_eps', default=1e-8, type=float, metavar='EPSILON',
                        help='Optimizer Epsilon (default: 1e-8)')
    parser.add_argument('--opt_betas', default=None, type=float, nargs='+', metavar='BETA',
                        help='Optimizer Betas (default: None, use opt default)')
    parser.add_argument('--clip_grad', type=float, default=None, metavar='NORM',
                        help='Clip gradient norm (default: None, no clipping)')
    parser.add_argument('--momentum', type=float, default=0.9, metavar='M',
                        help='SGD momentum (default: 0.9)')
    parser.add_argument('--weight_decay', type=float, default=0.05,
                        help='weight decay (default: 0.05)')
    parser.add_argument('--weight_decay_end', type=float, default=None, help="""Final value of the
        weight decay. We use a cosine schedule for WD and using a larger decay by
        the end of training improves performance for ViTs.""")

    parser.add_argument('--lr', type=float, default=1e-3, metavar='LR',
                        help='learning rate (default: 1e-3)')
    parser.add_argument('--layer_decay', type=float, default=0.75)

    parser.add_argument('--warmup_lr', type=float, default=1e-6, metavar='LR',
                        help='warmup learning rate (default: 1e-6)')
    parser.add_argument('--min_lr', type=float, default=1e-6, metavar='LR',
                        help='lower lr bound for cyclic schedulers that hit 0 (1e-5)')

    parser.add_argument('--warmup_epochs', type=int, default=5, metavar='N',
                        help='epochs to warmup LR, if scheduler supports')
    parser.add_argument('--warmup_steps', type=int, default=-1, metavar='N',
                        help='num of steps to warmup LR, will overload warmup_epochs if set > 0')

    # Augmentation parameters
    parser.add_argument('--color_jitter', type=float, default=0.4, metavar='PCT',
                        help='Color jitter factor (default: 0.4)')
    parser.add_argument('--num_sample', type=int, default=1,
                        help='Repeated_aug (default: 2)')
    parser.add_argument('--aa', type=str, default='rand-m7-n4-mstd0.5-inc1', metavar='NAME',
                        help='Use AutoAugment policy. "v0" or "original". " + "(default: rand-m7-n4-mstd0.5-inc1)'),
    parser.add_argument('--smoothing', type=float, default=0.1,
                        help='Label smoothing (default: 0.1)')
    parser.add_argument('--train_interpolation', type=str, default='bicubic',
                        help='Training interpolation (random, bilinear, bicubic default: "bicubic")')

    # Evaluation parameters
    parser.add_argument('--crop_pct', type=float, default=None)
    parser.add_argument('--short_side_size', type=int, default=224)
    parser.add_argument('--test_num_segment', type=int, default=5)
    parser.add_argument('--test_num_crop', type=int, default=3)

    # Random Erase params
    parser.add_argument('--reprob', type=float, default=0.25, metavar='PCT',
                        help='Random erase prob (default: 0.25)')
    parser.add_argument('--remode', type=str, default='pixel',
                        help='Random erase mode (default: "pixel")')
    parser.add_argument('--recount', type=int, default=1,
                        help='Random erase count (default: 1)')
    parser.add_argument('--resplit', action='store_true', default=False,
                        help='Do not random erase first (clean) augmentation split')

    # Mixup params
    parser.add_argument('--mixup', type=float, default=0.0,
                        help='mixup alpha, mixup enabled if > 0.')
    parser.add_argument('--cutmix', type=float, default=0.0,
                        help='cutmix alpha, cutmix enabled if > 0.')
    parser.add_argument('--cutmix_minmax', type=float, nargs='+', default=None,
                        help='cutmix min/max ratio, overrides alpha and enables cutmix if set (default: None)')
    parser.add_argument('--mixup_prob', type=float, default=0.0,
                        help='Probability of performing mixup or cutmix when either/both is enabled')
    parser.add_argument('--mixup_switch_prob', type=float, default=0.0,
                        help='Probability of switching to cutmix when both mixup and cutmix enabled')
    parser.add_argument('--mixup_mode', type=str, default='batch',
                        help='How to apply mixup/cutmix params. Per "batch", "pair", or "elem"')

    # Finetuning params
    parser.add_argument('--finetune', default='', help='finetune from checkpoint')
    parser.add_argument('--model_key', default='model|module', type=str)
    parser.add_argument('--model_prefix', default='', type=str)
    parser.add_argument('--init_scale', default=0.001, type=float)
    parser.add_argument('--use_checkpoint', action='store_true')
    parser.set_defaults(use_checkpoint=False)
    parser.add_argument('--use_mean_pooling', action='store_true')
    parser.set_defaults(use_mean_pooling=True)
    parser.add_argument('--use_cls', action='store_false', dest='use_mean_pooling')

    # Dataset parameters

    parser.add_argument('--eval_data_path', default=None, type=str,
                        help='dataset path for evaluation')
    parser.add_argument('--nb_classes', default=400, type=int,
                        help='number of the classification types')
    parser.add_argument('--imagenet_default_mean_and_std', default=True, action='store_true')
    parser.add_argument('--num_segments', type=int, default= 1)
    parser.add_argument('--num_frames', type=int, default= 16)
    parser.add_argument('--sampling_rate', type=int, default= 4)
    parser.add_argument('--data_set', default='Kinetics-400', choices=['kinetics100','kinetics400', 'mini-SSV2','SSV2', 'UCF101', 'HMDB51','image_folder'],
                        type=str, help='dataset')
    parser.add_argument('--output_dir', default='',
                        help='path where to save, empty for no saving')
    parser.add_argument('--log_dir', default=None,
                        help='path where to tensorboard log')
    # parser.add_argument('--device', default='cuda',
    #                     help='device to use for training / testing')
    parser.add_argument('--seed', default=0, type=int)
    parser.add_argument('--resume', default='',
                        help='resume from checkpoint')
    parser.add_argument('--auto_resume', action='store_true')
    parser.add_argument('--no_auto_resume', action='store_false', dest='auto_resume')
    parser.set_defaults(auto_resume=True)

    parser.add_argument('--save_ckpt', action='store_true')
    parser.add_argument('--no_save_ckpt', action='store_false', dest='save_ckpt')
    parser.set_defaults(save_ckpt=True)

    parser.add_argument('--start_epoch', default=0, type=int, metavar='N',
                        help='start epoch')
    parser.add_argument('--eval', action='store_true',
                        help='Perform evaluation only')
    parser.add_argument('--dist_eval', action='store_true', default=False,
                        help='Enabling distributed evaluation')
    parser.add_argument('--num_workers', default=10, type=int)
    parser.add_argument('--pin_mem', action='store_true',
                        help='Pin CPU memory in DataLoader for more efficient (sometimes) transfer to GPU.')
    parser.add_argument('--no_pin_mem', action='store_false', dest='pin_mem')
    parser.set_defaults(pin_mem=True)

    # distributed training parameters
    parser.add_argument('--world_size', default=1, type=int,
                        help='number of distributed processes')
    parser.add_argument('--local-rank', default=-1, type=int)
    parser.add_argument('--dist_on_itp', action='store_true')
    parser.add_argument('--dist_url', default='env://',
                        help='url used to set up distributed training')

    parser.add_argument('--enable_deepspeed', action='store_true', default=False)
    #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    parser.add_argument("--dataset", type=str, default="cifar10")
    parser.add_argument("--s_concept_set", type=str, default=None, 
                        help="path to concept set name")
    parser.add_argument("--t_concept_set", type=str, default=None, 
                        help="path to concept set name")
    parser.add_argument("--backbone", type=str, default="clip_RN50", help="Which pretrained model to use as backbone")
    parser.add_argument("--clip_name", type=str, default="ViT-B/16", help="Which CLIP model to use")

    parser.add_argument("--device", type=str, default="cuda", help="Which device to use")
    parser.add_argument("--batch_size", type=int, default=512, help="Batch size used when saving model/CLIP activations")
    parser.add_argument("--saga_batch_size", type=int, default=256, help="Batch size used when fitting final layer")
    parser.add_argument("--proj_batch_size", type=int, default=50000, help="Batch size to use when learning projection layer")

    parser.add_argument("--feature_layer", type=str, default='layer4', 
                        help="Which layer to collect activations from. Should be the name of second to last layer in the model")
    parser.add_argument("--activation_dir", type=str, default='saved_activations', help="save location for backbone and CLIP activations")
    parser.add_argument("--save_dir", type=str, default='saved_models', help="where to save trained models")
    parser.add_argument("--clip_cutoff", type=float, default=0.25, help="concepts with smaller top5 clip activation will be deleted")
    parser.add_argument("--proj_steps", type=int, default=1000, help="how many steps to train the projection layer for")
    parser.add_argument("--interpretability_cutoff", type=float, default=0.45, help="concepts with smaller similarity to target concept will be deleted")
    parser.add_argument("--lam", type=float, default=0.0007, help="Sparsity regularization parameter, higher->more sparse")
    parser.add_argument("--n_iters", type=int, default=1000, help="How many iterations to run the final layer solver for")
    parser.add_argument("--print", action='store_true', help="Print all concepts being deleted in this stage")
    parser.add_argument('--data_path', default='data/video_annotation/ucf101', type=str,
                        help='dataset path')
    parser.add_argument('--video_anno_path',type=str)
    parser.add_argument('--center_frame',action='store_true')
    parser.add_argument('--no_aug',type=bool,default=False)
    parser.add_argument('--saved_features',action='store_true')
    parser.add_argument('--dual_encoder', default='clip', choices=['clip', 'lavila', 'internvid'],
                        type=str, help='dataset')
    parser.add_argument('--dual_encoder_frames',type=int,default=16)
    parser.add_argument('--lavila_ckpt',type=str,default=None)
    return parser
# Out:
# /data/jong980812/anaconda3/envs/video-cbm/lib/python3.8/site-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /data/jong980812/anaconda3/envs/video-cbm/lib/python3.8/site-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %%
import json

def get_selected_args_from_file(args_file, selected_keys):
    # 파일을 읽어서 JSON 파싱
    with open(args_file, 'r') as f:
        args_dict = json.load(f)  # JSON 형식의 파일을 파이썬 딕셔너리로 변환

    # 선택한 key에 해당하는 값만 추출하여 argparse 형식으로 변환
    args_list = []
    for key in selected_keys:
        if key in args_dict:
            args_list.append(f'--{key}')  # key를 --key 형식으로 변환
            args_list.append(str(args_dict[key]))  # 값을 문자열로 변환해서 리스트에 추가

    return args_list

# %%
# change this to the  correct model dir, everything else should be taken care of
load_dir = "/data/jong980812/project/Video-CBM-two-stream/new_results/three_joint_no_prompt/new_norm/model/kinetics400_cbm_2024_10_23_20_36"
selected_keys = [
        'data_set', 'nb_classes', 'video_anno_path', 'data_path', 'lavila_ckpt', 'finetune', 'backbone'
    ]
args_list = get_selected_args_from_file(os.path.join(load_dir,'args.txt'),selected_keys)  # 파일에서 인자 리스트 생성
parser = parse_args()
argument = parser.parse_args(args_list)  # 파일에서 읽은 인자로 파싱
device = "cuda"
with open(os.path.join(load_dir, "args.txt"), "r") as f:
    args = json.load(f)
dataset = args["data_set"]
_, target_preprocess = data_utils.get_target_model(args["backbone"], device,argument)
print('done')
model,_ = cbm.load_cbm_triple(load_dir, device,argument)
# Out:
# Patch size = (16, 16)
# Load ckpt from /data/datasets/video_checkpoint/kinetics400/k400_finetune.pth
# Load state_dict by model_key = module
#
#
#
# *********** VMAE Load ***************
# done
# Patch size = (16, 16)
# Load ckpt from /data/datasets/video_checkpoint/kinetics400/k400_finetune.pth
# Load state_dict by model_key = module
#
#
#
# *********** VMAE Load ***************

# %%
val_d_probe = dataset+"_val"
cls_file = data_utils.LABEL_FILES[dataset]

val_data_t = data_utils.get_data(val_d_probe,args=argument)
val_data_t.visualize=True
print(val_data_t.center_frame)
argument.no_aug = True
argument.center_frame = True
val_pil_data = data_utils.get_data(val_d_probe,args=argument)
val_pil_data.end_point = 2
# Out:
# Number of the class = 400
# False
# Number of the class = 400

# %%
with open(cls_file, "r") as f:
    classes = f.read().split("\n")

with open(os.path.join(load_dir, 'spatial',"concepts.txt"), "r") as f:
    s_concepts = f.read().split("\n")
    s_concepts=["S:{}".format(word) for word in s_concepts]
s_concept_len = len(s_concepts)
with open(os.path.join(load_dir, 'temporal',"concepts.txt"), "r") as f:
    t_concepts = f.read().split("\n")
    t_concepts=["T:{}".format(word) for word in t_concepts]

t_concept_len = len(t_concepts)

with open(os.path.join(load_dir, 'place',"concepts.txt"), "r") as f:
    p_concepts = f.read().split("\n")
    p_concepts=["P:{}".format(word) for word in p_concepts]
    
p_concept_len = len(p_concepts)

st_concepts = s_concepts+t_concepts+p_concepts
s_concepts,t_concepts, p_concepts = st_concepts,st_concepts,st_concepts

# %%
st_concepts
# Out:
# ['S:air',
#  'S:algae',
#  'S:american flag',
#  'S:amplifier',
#  'S:animal',
#  'S:anvil',
#  'S:apple',
#  'S:apron',
#  'S:arcade',
#  'S:arena',
#  'S:arm',
#  'S:arrow',
#  'S:audience',
#  'S:avocado',
#  'S:award',
#  'S:baby',
#  'S:back',
#  'S:backpack',
#  'S:backyard',
#  'S:bacon',
#  'S:bag',
#  'S:balcony',
#  'S:ball',
#  'S:ballet shoes',
#  'S:bamboo',
#  'S:banana',
#  'S:band',
#  'S:banner',
#  'S:bar',
#  'S:barbell',
#  'S:barber',
#  'S:barn',
#  'S:barre',
#  'S:barrel',
#  'S:basket',
#  'S:basketball hoop',
#  'S:bass',
#  'S:bathtub',
#  'S:bat',
#  'S:batsman',
#  'S:batter',
#  'S:battery',
#  'S:beach',
#  'S:bead',
#  'S:beam',
#  'S:beans',
#  'S:beard',
#  'S:bee',
#  'S:belly',
#  'S:belly button',
#  'S:belt',
#  'S:bench',
#  'S:bib',
#  'S:bird',
#  'S:birthday',
#  'S:black',
#  'S:black pants',
#  'S:black shirt',
#  'S:black shorts',
#  'S:blanket',
#  'S:blender',
#  'S:blindfold',
#  'S:block',
#  'S:blue',
#  'S:blue carpet',
#  'S:blue shirt',
#  'S:board',
#  'S:board game',
#  'S:body',
#  'S:bolt',
#  'S:bookshelf',
#  'S:boot',
#  'S:bottle',
#  'S:bow',
#  'S:bowl',
#  'S:bowling pins',
#  'S:bowtie',
#  'S:box',
#  'S:boxer',
#  'S:boxing ring',
#  'S:bra',
#  'S:bracelet',
#  'S:brake',
#  'S:branch',
#  'S:brass',
#  'S:bread',
#  'S:brick',
#  'S:bridge',
#  'S:bridle',
#  'S:broccoli',
#  'S:broom',
#  'S:brown',
#  'S:brush',
#  'S:bubble',
#  'S:bucket',
#  'S:building',
#  'S:bull',
#  'S:bun',
#  'S:burner',
#  'S:bus',
#  'S:bush',
#  'S:butter',
#  'S:butterfly',
#  'S:button',
#  'S:cable',
#  'S:cage',
#  'S:calculator',
#  'S:calendar',
#  'S:calf',
#  'S:camera',
#  'S:can',
#  'S:candle',
#  'S:candy',
#  'S:canoe',
#  'S:canvas',
#  'S:cap',
#  'S:car seat',
#  'S:card',
#  'S:carousel',
#  'S:carpet',
#  'S:carrier',
#  'S:carrot',
#  'S:car',
#  'S:carving',
#  'S:case',
#  'S:casino',
#  'S:cat',
#  'S:catcher',
#  'S:cave',
#  'S:ceiling',
#  'S:cell phone',
#  'S:cellist',
#  'S:certificate',
#  'S:chain',
#  'S:chainsaw',
#  'S:chair',
#  'S:chalk',
#  'S:chalkboard',
#  'S:chandelier',
#  'S:charger',
#  'S:checkerboard',
#  'S:cheese',
#  'S:chest',
#  'S:child',
#  'S:chin',
#  'S:chocolate',
#  'S:choir',
#  'S:chopsticks',
#  'S:chord',
#  'S:church',
#  'S:cigar',
#  'S:circle',
#  'S:circuit board',
#  'S:circus',
#  'S:city',
#  'S:clay',
#  'S:cleaner',
#  'S:cliff',
#  'S:climber',
#  'S:clock',
#  'S:cloth',
#  'S:cloud',
#  'S:club',
#  'S:coach',
#  'S:coffee',
#  'S:coffee maker',
#  'S:coin',
#  'S:collar',
#  'S:comb',
#  'S:concrete',
#  'S:cone',
#  'S:container',
#  'S:cookie',
#  'S:coral',
#  'S:cord',
#  'S:cork',
#  'S:corn',
#  'S:couch',
#  'S:counter',
#  'S:court',
#  'S:cowboy hat',
#  'S:crane',
#  'S:cream',
#  'S:crib',
#  'S:crochet hook',
#  'S:crowd',
#  'S:crust',
#  'S:cucumber',
#  'S:cup',
#  'S:cupcake',
#  'S:cutting board',
#  'S:dancer',
#  'S:darkness',
#  'S:dart',
#  'S:dartboard',
#  'S:dashboard',
#  'S:deck',
#  'S:deer',
#  'S:desert',
#  'S:desk',
#  'S:detergent',
#  'S:diaper',
#  'S:dice',
#  'S:dish',
#  'S:diver',
#  'S:divider',
#  'S:dock',
#  'S:dog',
#  'S:doll',
#  'S:dollar',
#  'S:donkey',
#  'S:donut',
#  'S:door',
#  'S:dough',
#  'S:dragon',
#  'S:drain',
#  'S:drawer',
#  'S:dress',
#  'S:drill',
#  'S:driver',
#  'S:drumsticks',
#  'S:dryer',
#  'S:duck',
#  'S:dumbbell',
#  'S:dye',
#  'S:ear',
#  'S:earring',
#  'S:egg',
#  'S:engine',
#  'S:eraser',
#  'S:eyebrow',
#  'S:eyebrow pencil',
#  'S:eyelash',
#  'S:eyelid',
#  'S:eyeliner',
#  'S:eyes',
#  'S:fabric',
#  'S:face',
#  'S:fan',
#  'S:faucet',
#  'S:feeder',
#  'S:fence',
#  'S:field',
#  'S:fighter',
#  'S:fingerboard',
#  'S:fingers',
#  'S:fire',
#  'S:fire hose',
#  'S:fire hydrant',
#  'S:fire truck',
#  'S:fireman',
#  'S:fireworks',
#  'S:fishing pole',
#  'S:fist',
#  'S:fitness',
#  'S:flag',
#  'S:flames',
#  'S:flippers',
#  'S:float',
#  'S:flock',
#  'S:floor',
#  'S:flour',
#  'S:flower',
#  'S:foil',
#  'S:fold',
#  'S:food',
#  'S:foot',
#  'S:football field',
#  'S:footprints',
#  'S:forest',
#  'S:fork',
#  'S:forklift',
#  'S:fountain',
#  'S:fries',
#  'S:front',
#  'S:fruit',
#  'S:frying pan',
#  'S:fuel',
#  'S:fur',
#  'S:furnace',
#  'S:game',
#  'S:garage',
#  'S:garbage truck',
#  'S:garlic',
#  'S:gas',
#  'S:gas tank',
#  'S:gauge',
#  'S:gift',
#  'S:glass',
#  'S:glasses',
#  'S:glitter',
#  'S:globe',
#  'S:glove',
#  'S:glow',
#  'S:glue',
#  'S:goal',
#  'S:goalie',
#  'S:goat',
#  'S:goggles',
#  'S:cart',
#  'S:golfers',
#  'S:gown',
#  'S:graffiti',
#  'S:grape',
#  'S:grass',
#  'S:grate',
#  'S:green beans',
#  'S:grill',
#  'S:grinder',
#  'S:grip',
#  'S:groceries',
#  'S:ground',
#  'S:guns',
#  'S:gutter',
#  'S:gym',
#  'S:hair dryer',
#  'S:hairbrush',
#  'S:ham',
#  'S:hamburger',
#  'S:hammer',
#  'S:hand',
#  'S:handbag',
#  'S:handlebar',
#  'S:harness',
#  'S:hat',
#  'S:head',
#  'S:headphones',
#  'S:heart',
#  'S:helicopter',
#  'S:helmet',
#  'S:high chair',
#  'S:highway',
#  'S:hill',
#  'S:hive',
#  'S:hockey stick',
#  'S:hole',
#  'S:home plate',
#  'S:honey',
#  'S:honeycomb',
#  'S:hood',
#  'S:hoodie',
#  'S:hoof',
#  'S:hook',
#  'S:hoop',
#  'S:horizon',
#  'S:horn',
#  'S:horse',
#  'S:hose',
#  'S:hot dog',
#  'S:house',
#  'S:hubcap',
#  'S:hurdle',
#  'S:ice',
#  'S:ice cream cone',
#  'S:inflatable',
#  'S:ink',
#  'S:instrument',
#  'S:ipad',
#  'S:ipod',
#  'S:iron',
#  'S:island',
#  'S:jacket',
#  'S:jar',
#  'S:jeans',
#  'S:jeep',
#  'S:jelly',
#  'S:jersey',
#  'S:joker',
#  'S:joystick',
#  'S:judge',
#  'S:juicer',
#  'S:kangaroo',
#  'S:karate',
#  'S:kayak',
#  'S:ketchup',
#  'S:kettle',
#  'S:keys',
#  'S:kids',
#  'S:kilt',
#  'S:king',
#  'S:kitchen',
#  'S:knee',
#  'S:knee pads',
#  'S:knife',
#  'S:knobs',
#  'S:knot',
#  'S:lake',
#  'S:lamp',
#  'S:lane',
#  'S:lane markers',
#  'S:laptop',
#  'S:lawn',
#  'S:lawn mower',
#  'S:leaf',
#  'S:leash',
#  'S:leg',
#  'S:lemon',
#  'S:letter',
#  'S:lettuce',
#  'S:license plate',
#  'S:lid',
#  'S:life jacket',
#  'S:lifeguard',
#  'S:light',
#  'S:lighter',
#  'S:lime',
#  'S:link',
#  'S:lips',
#  'S:lipstick',
#  'S:logo',
#  'S:logs',
#  'S:loop',
#  'S:lounge chair',
#  'S:machine',
#  'S:magazine',
#  'S:makeup',
#  'S:map',
#  'S:marker',
#  'S:mask',
#  'S:mat',
#  'S:mattress',
#  'S:mayo',
#  'S:meat',
#  'S:medal',
#  'S:message',
#  'S:metal',
#  'S:mic',
#  'S:microwave',
#  'S:milk',
#  'S:mirror',
#  'S:mixer',
#  'S:model',
#  'S:money',
#  'S:monitor',
#  'S:moon',
#  'S:motherboard',
#  'S:mountain',
#  'S:mouse',
#  'S:mouth',
#  'S:mouthpiece',
#  'S:mud',
#  'S:mug',
#  'S:mushroom',
#  'S:music stand',
#  'S:musician',
#  'S:mustache',
#  'S:mustard',
#  'S:nail polish',
#  'S:name tag',
#  'S:necklace',
#  'S:needle',
#  'S:net',
#  'S:night',
#  'S:nipple',
#  'S:noodles',
#  'S:nose',
#  'S:number',
#  'S:oar',
#  'S:oil',
#  'S:olive',
#  'S:onion',
#  'S:orange',
#  'S:orchestra',
#  'S:organ',
#  'S:ornament',
#  'S:oven',
#  'S:owl',
#  'S:pacifier',
#  'S:paddle',
#  'S:paddleboard',
#  'S:pads',
#  'S:pail',
#  'S:paintbrush',
#  'S:pajamas',
#  'S:pallets',
#  'S:palm tree',
#  'S:pan',
#  'S:pancakes',
#  'S:pants',
#  'S:paper towel',
#  'S:paper towel dispenser',
#  'S:papers',
#  'S:parachute',
#  'S:parade',
#  'S:park',
#  'S:parking lot',
#  'S:party',
#  'S:path',
#  'S:pavement',
#  'S:paw',
#  'S:peanut butter',
#  'S:pearl',
#  'S:peas',
#  'S:pedicure',
#  'S:pen',
#  'S:pencils',
#  'S:penguin',
#  'S:pepper',
#  'S:pepperoni',
#  'S:pew',
#  'S:piano bench',
#  'S:piano keys',
#  'S:pig',
#  'S:pigeon',
#  'S:pillow',
#  'S:pineapple',
#  'S:pink',
#  'S:pink hair',
#  'S:pink pants',
#  'S:pink shirt',
#  'S:pins',
#  'S:pipe',
#  'S:pitcher',
#  'S:pizza cutter',
#  'S:pizza pan',
#  'S:plaid',
#  'S:plane',
#  'S:planet',
#  'S:plant',
#  'S:plate',
#  'S:player',
#  'S:pliers',
#  'S:plow',
#  'S:pocket',
#  'S:podium',
#  'S:poker chip',
#  'S:pole',
#  'S:polish',
#  'S:polka dot',
#  'S:pom pom',
#  'S:pond',
#  'S:ponytail',
#  'S:pope',
#  'S:poster',
#  'S:pot',
#  'S:potato',
#  'S:pot',
#  'S:pottery wheel',
#  'S:power supply',
#  'S:prayer',
#  'S:precipitation',
#  'S:priest',
#  'S:printer',
#  'S:projector',
#  'S:puck',
#  'S:pulpit',
#  'S:pump',
#  'S:pumpkin',
#  'S:punch',
#  'S:purple',
#  'S:putter',
#  'S:pyramid',
#  'S:queen',
#  'S:rabbit',
#  'S:race',
#  'S:rack',
#  'S:racket',
#  'S:radar',
#  'S:radio',
#  'S:rag',
#  'S:rail',
#  'S:rain',
#  'S:rake',
#  'S:ramp',
#  'S:razor',
#  'S:record',
#  'S:red',
#  'S:red bull',
#  'S:reef',
#  'S:referee',
#  'S:refrigerator',
#  'S:rein',
#  'S:remote',
#  'S:ribbon',
#  'S:rib',
#  'S:rice',
#  'S:rider',
#  'S:rim',
#  'S:ring',
#  'S:rink',
#  'S:ripple',
#  'S:river',
#  'S:road',
#  'S:robe',
#  'S:robot',
#  'S:rock',
#  'S:rod',
#  'S:rodeo',
#  'S:rolling pin',
#  'S:roof',
#  'S:rope',
#  'S:rose',
#  'S:rug',
#  'S:ruler',
#  'S:runner',
#  'S:saddle',
#  'S:sailor',
#  'S:salt',
#  'S:sandals',
#  'S:santa',
#  'S:santa hat',
#  'S:satellite',
#  'S:sauce',
#  'S:sausage',
#  'S:saw',
#  'S:scaffolding',
#  'S:scanner',
#  'S:scarf',
#  'S:scissors',
#  'S:score',
#  'S:scoreboard',
#  'S:screen',
#  'S:screw',
#  'S:screwdriver',
#  'S:sea',
#  'S:seat',
#  'S:seatbelt',
#  'S:seaweed',
#  'S:shade',
#  'S:shadow',
#  'S:shampoo',
#  'S:shark',
#  'S:sharpener',
#  'S:shaving brush',
#  'S:shaving cream',
#  'S:shaving razor',
#  'S:shear',
#  'S:shearer',
#  'S:shearing machine',
#  'S:shears',
#  'S:shed',
#  'S:sheep',
#  'S:sheet',
#  'S:sheet music',
#  'S:shelf',
#  'S:shield',
#  'S:shingles',
#  'S:ship',
#  'S:shirt',
#  'S:shirtless',
#  'S:shisha',
#  'S:shoe',
#  'S:shoe box',
#  'S:shoe lace',
#  'S:shoe polish',
#  'S:shoe shine brush',
#  'S:shoe shine stand',
#  'S:cart ',
#  'S:shorts',
#  'S:shoulder',
#  'S:shovel',
#  'S:shower curtain',
#  'S:shower head',
#  'S:shredder',
#  'S:sidewalk',
#  'S:sign',
#  'S:sink',
#  'S:skates',
#  'S:skewer',
#  'S:ski',
#  'S:ski lift',
#  'S:ski pole',
#  'S:skier',
#  'S:skin',
#  'S:skirt',
#  'S:skull',
#  'S:sky',
#  'S:skyscraper',
#  'S:sled',
#  'S:sleeve',
#  'S:slice',
#  'S:slide',
#  'S:slope',
#  'S:smile',
#  'S:snack',
#  'S:snake',
#  'S:snow',
#  'S:snowball',
#  'S:snowflakes',
#  'S:soap',
#  'S:soap dispenser',
#  'S:soccer player',
#  'S:sock',
#  'S:soda',
#  'S:soil',
#  'S:spark',
#  'S:sparkler',
#  'S:sparks',
#  'S:spatula',
#  'S:speaker',
#  'S:spectator',
#  'S:spectators',
#  'S:speed',
#  'S:speedometer',
#  'S:spices',
#  'S:splash',
#  'S:sponge',
#  'S:spoon',
#  'S:squat rack',
#  'S:stable',
#  'S:stack',
#  'S:stadium',
#  'S:stage',
#  'S:stairs',
#  'S:stall',
#  'S:stand',
#  'S:stapler',
#  'S:star',
#  'S:statue',
#  'S:steak',
#  'S:steam',
#  'S:steering wheel',
#  'S:steps',
#  'S:stethoscope',
#  'S:sticks',
#  'S:stirrups',
#  'S:stool',
#  'S:stop sign',
#  'S:stove',
#  'S:strap',
#  'S:straw',
#  'S:street',
#  'S:street light',
#  'S:strings',
#  'S:stroller',
#  'S:stuffed animal',
#  'S:stump',
#  'S:stylist',
#  'S:suit',
#  'S:suitcase',
#  'S:sun',
#  'S:sunflower',
#  'S:sunglasses',
#  'S:sunlight',
#  'S:sunset',
#  'S:surfboard',
#  'S:swan',
#  'S:sweater',
#  'S:swim cap',
#  'S:swimming pool',
#  'S:swimsuit',
#  'S:tablecloth',
#  'S:table',
#  'S:tablet',
#  'S:tail',
#  'S:tan',
#  'S:tanks',
#  'S:tape',
#  'S:tape measure',
#  'S:target',
#  'S:tattoo machine',
#  'S:tea pot',
#  'S:team',
#  'S:teddy bear',
#  'S:teeth',
#  'S:temperature',
#  'S:tennis ball',
#  'S:tennis racket',
#  'S:tent',
#  'S:thumb',
#  'S:tiger',
#  'S:tile',
#  'S:time',
#  'S:tire',
#  'S:tissue',
#  'S:toast',
#  'S:toaster',
#  'S:toddler',
#  'S:toes',
#  'S:toilet bowl',
#  'S:toilet brush',
#  'S:toilet paper',
#  'S:toilet seat',
#  'S:tomato',
#  'S:tongs',
#  'S:tongue',
#  'S:tool',
#  'S:toothbrush holder',
#  'S:toothpaste',
#  'S:torch',
#  'S:tortilla',
#  'S:towel',
#  'S:tower',
#  'S:toy',
#  'S:toy car',
#  'S:track',
#  'S:traffic',
#  'S:traffic light',
#  'S:trailer',
#  'S:train',
#  'S:trash',
#  'S:trash can',
#  'S:tray',
#  'S:tree',
#  'S:triangle',
#  'S:trophy',
#  'S:trowel',
#  'S:truck',
#  'S:trunk',
#  'S:tub',
#  'S:tuba',
#  'S:tube',
#  'S:tunnel',
#  'S:turntable',
#  'S:turtle',
#  'S:tv',
#  'S:udder',
#  'S:umbrella',
#  'S:umpire',
#  'S:uniform',
#  'S:vacuum',
#  'S:van',
#  'S:vase',
#  'S:vegetables',
#  'S:vest',
#  'S:video',
#  'S:wall',
#  'S:wallpaper',
#  'S:washer',
#  'S:washing machine',
#  'S:watch',
#  'S:water',
#  'S:waterfall',
#  'S:watering can',
#  'S:waves',
#  'S:weather map',
#  'S:weight',
#  'S:wetsuit',
#  'S:wheels',
#  'S:whiskers',
#  'S:white',
#  'S:white pants',
#  'S:white shirt',
#  'S:wicker',
#  'S:wii',
#  'S:wii controller',
#  'S:wind',
#  'S:window',
#  'S:windshield',
#  'S:wine',
#  'S:wine bottle',
#  'S:wine glass',
#  'S:wires',
#  'S:wood',
#  'S:wool',
#  'S:words',
#  'S:workbench',
#  'S:worker',
#  'S:woven',
#  'S:wrench',
#  'S:wrist',
#  'S:yellow',
#  'S:yolk',
#  'T:Accept something.',
#  'T:Add something on top.',
#  'T:Adjust something.',
#  'T:Adorn something with something.',
#  'T:Aim at something.',
#  'T:Aim toward something.',
#  'T:Align something in a straight line.',
#  'T:Anchor something near something.',
#  'T:Appreciate something special.',
#  'T:Approach something with something.',
#  'T:Arch something over something.',
#  'T:Arrange something on something.',
#  'T:Ascend something with careful movements.',
#  'T:Assemble something with precision.',
#  'T:Attach something to something.',
#  'T:Bait something with something.',
#  'T:Bake something in something.',
#  'T:Balance on something.',
#  'T:Bang something in rhythm.',
#  'T:Bathe something.',
#  'T:Beat something in rhythm with something.',
#  'T:Beat something with something.',
#  'T:Bend towards something.',
#  'T:Bend something.',
#  'T:Bet something.',
#  'T:Bind off something.',
#  'T:Bite into something.',
#  'T:Blast something with something.',
#  'T:Blend something with something.',
#  'T:Block something.',
#  'T:Blow into something.',
#  'T:Blow out something.',
#  'T:Boil something.',
#  'T:Bounce on something.',
#  'T:Bounce something repeatedly.',
#  'T:Bow across something.',
#  'T:Bowl something down the pitch.',
#  'T:Brakes slow something.',
#  'T:Breathe deeply.',
#  'T:Browse something.',
#  'T:Brush something.',
#  'T:Buff something with something.',
#  'T:Bump something for encouragement.',
#  'T:Canter around something.',
#  'T:Carry something.',
#  'T:Cast something into something.',
#  'T:Catch something.',
#  'T:Celebrate something.',
#  'T:Change something.',
#  'T:Chant something.',
#  'T:Chase something.',
#  'T:Check something for proper alignment.',
#  'T:Check something for stability.',
#  'T:Check something repeatedly.',
#  'T:Cheers with something.',
#  'T:Choose something.',
#  'T:Clap something.',
#  'T:Clean something.',
#  'T:Clear something from something.',
#  'T:Climb down something carefully.',
#  'T:Climb something carefully.',
#  'T:Climb up something.',
#  'T:Clip something into something.',
#  'T:Clip something off something.',
#  'T:Coat something with something.',
#  'T:Collect something from something.',
#  'T:Color something vibrant.',
#  'T:Compete against something in something.',
#  'T:Condition something to keep it smooth.',
#  'T:Connect something to something.',
#  'T:Connect with something.',
#  'T:Control something.',
#  'T:Cook something.',
#  'T:Count something.',
#  'T:Cover something with something.',
#  'T:Crack something into something.',
#  'T:Cradle something.',
#  'T:Crash something against something.',
#  'T:Crawl toward something.',
#  'T:Crease something along the edge.',
#  'T:Create something loud.',
#  'T:Create something with something.',
#  'T:Cross something over something.',
#  'T:Cross the finish line of something.',
#  'T:Crunch on something fresh.',
#  'T:Cuddle something close.',
#  'T:Cut something.',
#  'T:Dampen something.',
#  'T:Dance around something in rhythm.',
#  'T:Dangle something over the edge.',
#  'T:Deal something to everyone.',
#  'T:Defend something from something fiercely.',
#  'T:Deliver something to something.',
#  'T:Descend down something.',
#  'T:Dice something into small pieces.',
#  'T:Dig something.',
#  'T:Dip something in something.',
#  'T:Discard something in something.',
#  'T:Discover something.',
#  'T:Dispose of something.',
#  'T:Dive into something.',
#  'T:Dodge something.',
#  'T:Drain something into something.',
#  'T:Draw back something.',
#  'T:Draw something on the surface.',
#  'T:Draw something out.',
#  'T:Dribble something.',
#  'T:Drill a hole in something.',
#  'T:Drizzle something on top.',
#  'T:Drop something onto something.',
#  'T:Dry something.',
#  'T:Dust something.',
#  'T:Embrace something tightly.',
#  'T:Encourage something exciting.',
#  'T:Engage something for stability.',
#  'T:Ensuring something is aligned properly.',
#  'T:Equip something for something.',
#  'T:Erase something.',
#  'T:Escaped from something.',
#  'T:Evading something.',
#  'T:Examine something closely.',
#  'T:Exchange something for something.',
#  'T:Execute a move on something.',
#  'T:Exfoliate something before something.',
#  'T:Exhale something gently.',
#  'T:Explore something.',
#  'T:Express emotions through something.',
#  'T:Extend something toward something.',
#  'T:Fall off something.',
#  'T:Fan something out onto something.',
#  'T:Feed something.',
#  'T:Fell onto something.',
#  'T:Fidget with something.',
#  'T:Field something quickly.',
#  'T:File something to smooth out the edges.',
#  'T:Fill something with something.',
#  'T:Find something.',
#  'T:Finger something correctly.',
#  'T:Finish something with something.',
#  'T:Fire something in something.',
#  'T:Flip over something.',
#  'T:Flip through something.',
#  'T:Float down something.',
#  'T:Flow through something.',
#  'T:Fluff something with a quick motion.',
#  'T:Flush something with something.',
#  'T:Fly off something with grace.',
#  ...]

# %% [markdown]
# ## Measure accuracy

# %%
# import cbm_utils
# accuracy = cbm_utils.get_accuracy_cbm(model, val_data_t, device,32,8)
# print("Accuracy: {:.2f}%".format(accuracy*100))

# %% [markdown]
# ## Show final layer weights for some classes

# %% [markdown]
# You can build a Sankey diagram of weights by copying the incoming weights printed below into https://sankeymatic.com/build/

# %%
to_show = random.choices([i for i in range(len(classes))], k=2)
to_show=[72,121,14]
for i in to_show:
    print("Output class:{} - {}\n".format(i, classes[i]))
    # for context in ['Spatial','Temporal']:
    # model = s_model if context=='Spatial' else t_model
    concepts = st_concepts
    print(f" Incoming weights:")
    for j in range(len(concepts)):
        if torch.abs(model.final.weight[i,j])>0.05:
            print("{} [{:.4f}] {}".format(concepts[j], model.final.weight[i,j], classes[i]))
    print()
# Out:
# Output class:72 - cooking on campfire
#
#  Incoming weights:
# S:fire [0.5934] cooking on campfire
# T:Fire something in something. [0.2956] cooking on campfire
# T:Grill something. [0.3508] cooking on campfire
# T:Roast something. [0.1716] cooking on campfire
# P:amusement arcade [-0.1630] cooking on campfire
# P:auto showroom [-0.1540] cooking on campfire
# P:campsite [0.2199] cooking on campfire
# P:toyshop [-0.2220] cooking on campfire
#
# Output class:121 - extinguishing fire
#
#  Incoming weights:
# S:cellist [-0.0975] extinguishing fire
# S:fire [0.4471] extinguishing fire
# S:fire hose [0.0899] extinguishing fire
# S:fire truck [0.5616] extinguishing fire
# S:fireman [0.6611] extinguishing fire
# T:Fire something in something. [0.1892] extinguishing fire
# T:Unlock something. [-0.0589] extinguishing fire
#
# Output class:14 - barbequing
#
#  Incoming weights:
# S:flower [-0.0576] barbequing
# S:grill [0.3355] barbequing
# S:meat [0.1298] barbequing
# S:ornament [-0.1197] barbequing
# S:pearl [-0.0959] barbequing
# S:rib [0.3218] barbequing
# T:Express emotions through something. [-0.1384] barbequing
# T:Grill something. [1.1080] barbequing
# T:Marinate something in something. [0.3678] barbequing
# T:Order something from the menu. [0.0669] barbequing
# T:Serve something with a side of something. [0.1206] barbequing
# P:general store, outdoor [0.0608] barbequing
# P:market, outdoor [0.1334] barbequing
# P:restaurant patio [0.2103] barbequing

# %%
print(model.final.weight.shape)
zero_count = torch.sum(model.final.weight == 0).item()
print(zero_count)

# %%
s_model.final.weight.numel()

# %%
to_show = [i for i in range(argument.nb_classes)]#random.choices([i for i in range(len(classes))], k=100)
save_path = load_dir.split('model')[0]
# top_weights, top_weight_ids = torch.topk(model.final.weight, k=5, dim=1)
# bottom_weights, bottom_weight_ids = torch.topk(model.final.weight, k=5, dim=1, largest=False)

# for context in ['spatial','temporal']:
    # model = s_model if context=='spatial' else t_model
concepts = st_concepts#s_concepts if context=='spatial' else t_concepts
top_weights, top_weight_ids = torch.topk(model.final.weight, k=5, dim=1)
bottom_weights, bottom_weight_ids = torch.topk(model.final.weight, k=5, dim=1, largest=False)
with open(os.path.join(save_path,f"output.txt"), "w") as f:
    for i in to_show:
        f.write("Class {} - {}\n".format(i, classes[i]))
        
        out = "Highest weights: "
        for j in range(top_weights.shape[1]):
            idx = int(top_weight_ids[i, j].cpu())
            out += "{}:{:.3f}, ".format(concepts[idx], top_weights[i, j])
        f.write(out + "\n")
        
        out = "Lowest weights: "
        for j in range(bottom_weights.shape[1]):
            idx = int(bottom_weight_ids[i, j].cpu())
            out += "{}:{:.3f}, ".format(concepts[idx], bottom_weights[i, j])
        f.write(out + "\n\n")

# %%
# Some features may not have any non-zero outgoing weights, 
# i.e. these are not used by the model and should be deleted for better performance
s_weight_contribs = torch.sum(torch.abs(s_model.final.weight), dim=0)
t_weight_contribs = torch.sum(torch.abs(t_model.final.weight), dim=0)
print("Spatal- Num concepts with outgoing weights:{}/{}".format(torch.sum(s_weight_contribs>1e-5), len(s_weight_contribs)))
print("Temporal - Num concepts with outgoing weights:{}/{}".format(torch.sum(t_weight_contribs>1e-5), len(t_weight_contribs)))

# %%
len(val_data_t)

# %%
from tqdm import tqdm
data_num = len(val_data_t)
so_tx=0
sx_to=0
sx_tx=0
with torch.no_grad():
    for i in tqdm(range(1000)):
        x, label = val_data_t[i]
        x = x.unsqueeze(0).to(device)
        s_outputs, _ = s_model(x)
        t_outputs,_ = t_model(x)
        s_correct = s_outputs.argmax()==label
        t_correct = t_outputs.argmax()==label
        if (s_correct and not t_correct):so_tx+=1
        elif (not s_correct and  t_correct):sx_to+=1
        elif (not s_correct and not t_correct):sx_tx+=1
        
        if ((i+1)%100)==0:
            print(f'so_tx: {so_tx}/{i+1}')
            print(f'sx_to: {sx_to}/{i+1}')
            print(f'sx_tx: {sx_tx}/{i+1}')

# %%
print(f'so_tx: {so_tx}')
print(f'sx_to: {sx_to}')

# %%
import torch
import numpy as np
from PIL import Image
from IPython.display import display, Image as IPImage
# Dataloader로부터 얻은 tensor (C, T, H, W)

def visualize_gif(image,label,path,index,img_ind):
    tensor = image
    video_name = path.split('/')[-1].split('.')[0]
    gif_path = f'./gif/{img_ind}_{video_name}_{index}.gif'
    image_folder = f'./images/{img_ind}_{video_name}_{index}/'
    os.makedirs(image_folder, exist_ok=True)
    # if not os.path.exists(gif_path):
    # 텐서를 (T, H, W, C)로 변환
    tensor = tensor.permute(1, 2, 3, 0)  # (T, H, W, C)

    # 텐서를 numpy 배열로 변환
    tensor_np = tensor.numpy()

    # 이미지 리스트 생성
    images = []
    for i in range(tensor_np.shape[0]):
        # 각 프레임을 (H, W, C) 형태로 변환 후 0~255 범위로 스케일링
        frame = ((tensor_np[i] - tensor_np[i].min()) / (tensor_np[i].max() - tensor_np[i].min()) * 255).astype(np.uint8)
        frame_image = Image.fromarray(frame)
        images.append(frame_image)
        # frame_image_path = os.path.join(image_folder, f'77688_0000{i+10}.png')
        # frame_image.save(frame_image_path)
    # GIF로 저장 (duration은 각 프레임 사이의 시간, 100ms = 0.1초)
    

    images[0].save(gif_path, save_all=True, append_images=images[1:], duration=100, loop=0)
    # else:
    #     pass
    # Jupyter에서 GIF 표시
    display(IPImage(filename=gif_path))

    # print("Jupyter Notebook에서 GIF를 표시합니다.")

# %% [markdown]
# ## Explain model reasoning for random inputs

# %%
from torchvision.transforms import ToPILImage

from IPython.display import display, HTML, Video
# to_display = random.sample([i for i in range(len(val_pil_data))], k=20)
to_display =[i+111 for i in range(5)]
to_display =[137,638,1446,1942]#333:  kicking soccer ball
# to_display = [762, 799, 1073, 1214, 1283, 3062, 3293, 3520, 3890, 4317]# 4660, 5308, 5949, 6028, 6048, 6132, 6168, 6291]#, 6295, 7587, 7621, 8579, 8607, 8787, 9363, 9729, 9783, 9859, 9990, 10275, 10721, 11045, 11194, 12124, 12190, 12471, 12482, 13327, 13633, 13674, 14517, 14597, 16094, 16481, 16937, 17242, 17360, 17829, 18544, 19577]#hitting baseball
# to_display = [925, 1175, 1525, 1716, 2003, 2071, 2210, 3116, 3322, 4522, 4864, 4991, 5814, 6129, 6195, 6207, 6591, 7122, 8363, 8564, 8682, 9138]#, 9410, 9420, 9617, 9774, 9868, 10064, 10437, 11182, 11995, 12055, 12065, 12449, 12888, 13019, 13314, 14884, 15054, 15552, 15759, 16057, 16331, 16571, 17008, 17344, 17888, 18058, 18096, 19453]
# to_display=[0, 55, 587, 1201, 1595, 1651, 2057, 2723, 2901, 3077, 3873, 3960]
to_display=[0]#,16, 454, 489, 751, 790, 1168, 2342,4040, 4276, 4610, 4882, 5053, 5191, 6248]
import matplotlib.pyplot as plt
to_pil_image = ToPILImage()

with torch.no_grad():
    for i in to_display:
        visual_index=2
        val_pil_data.end_point = visual_index
        image,label ,path= val_pil_data[i]
        x, _ ,_= val_data_t[i]
        x = x.unsqueeze(0).to(device)
        x=x[:,visual_index]
        visualize_gif(image,label ,path,visual_index,i)
        s_outputs, s_concept_act = model(x)
        # image = to_pil_image(image)
        fig, axs = plt.subplots(1, 1, figsize=(5, 5))
        title_anno={'spatial':None,'temporal':None}
        # for j, context in enumerate(['spatial', 'temporal']):

        concepts = s_concepts
        outputs, concept_act = model(x)
        top_logit_vals, top_classes = torch.topk(outputs[0], dim=0, k=2)
        conf = torch.nn.functional.softmax(outputs[0], dim=0)   
        title_anno['spatial']="Image:{} Gt:{}, 1st Pred:{}, {:.3f}, 2nd Pred:{}, {:.3f}".format(i, classes[int(label)], classes[top_classes[0]], top_logit_vals[0],
                                                                    classes[top_classes[1]], top_logit_vals[1])

        
        for k in range(1):  
            contributions = concept_act[0]*model.final.weight[top_classes[k], :]
            feature_names = [("NOT " if concept_act[0][i] < 0 else "") + concepts[i] for i in range(len(concepts))]
            values = contributions.cpu().numpy()
            max_display = min(int(sum(abs(values)>0.005))+1, 8)
            title = "Pred:{} - Conf: {:.3f} - Logit:{:.2f} - Bias:{:.2f}".format(classes[top_classes[k]],
                            conf[top_classes[k]], top_logit_vals[k], model.final.bias[top_classes[k]])
            # plt.sca(axs[0])
            plots.bar(values, feature_names, max_display=max_display, show=False,title=title, fontsize=12, pos_color=(1, 0, 0))
            # plots.bar(values, feature_names, max_display=max_display, title=title, fontsize=16,pos_color=(1,0,0) if context=='spatial' else (0,0,1))
        # plt.tight_layout(pad=40.0
        print(title_anno['spatial'],sep=' '*50)
        plt.subplots_adjust(left=0.1, right=2.5, top=0.85, bottom=0.1, wspace=0.4)
        plt.show()
# Out:
# Image:0 Gt:somersaulting, 1st Pred:somersaulting, 4.607, 2nd Pred:tickling, 4.495
